# %%
# !pip install grpcio protobuf
# !pip install torch numpy gymnasium
# Out:
# Requirement already satisfied: grpcio in /usr/local/lib/python3.11/dist-packages (1.73.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (5.29.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.11/dist-packages (1.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Using cached nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Using cached nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Using cached nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Using cached nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Using cached nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Using cached nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Using cached nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Using cached nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Using cached nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
# Using cached nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
# Using cached nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 843.9 kB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
# Traceback (most recent call last):
#   File
# "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/base_command.py",
# line 179, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File
# "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/req_command.py", line
# 67, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File
# "/usr/local/lib/python3.11/dist-packages/pip/_internal/commands/install.py",
# line 377, in run
#     requirement_set = resolver.resolve(
#                       ^^^^^^^^^^^^^^^^^
#   File
# "/usr/local/lib/python3.11/dist-packages/pip/_internal/resolution/resolvelib/res
# olver.py", line 179, in resolve
#     self.factory.preparer.prepare_linked_requirements_more(reqs)
#   File
# "/usr/local/lib/python3.11/dist-packages/pip/_internal/operations/prepare.py",
# line 554, in prepare_linked_requirements_more
#     self._complete_partial_requirements(
#   File
# "/usr/local/lib/python3.11/dist-packages/pip/_internal/operations/prepare.py",
# line 469, in _complete_partial_requirements
#     for link, (filepath, _) in batch_download:
#   File
# "/usr/local/lib/python3.11/dist-packages/pip/_internal/network/download.py",
# line 185, in __call__
#     content_file.write(chunk)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/pip3", line 10, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/main.py", line
# 80, in main
#     return command.main(cmd_args)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File
# "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/base_command.py",
# line 100, in main
#     return self._main(args)
#            ^^^^^^^^^^^^^^^^
#   File
# "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/base_command.py",
# line 232, in _main
#     return run(options, args)
#            ^^^^^^^^^^^^^^^^^^
#   File
# "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/base_command.py",
# line 215, in exc_logging_wrapper
#     logger.critical("Operation cancelled by user")
#   File "/usr/lib/python3.11/logging/__init__.py", line 1536, in critical
#     self._log(CRITICAL, msg, args, **kwargs)
#   File "/usr/lib/python3.11/logging/__init__.py", line 1634, in _log
#     self.handle(record)
#   File "/usr/lib/python3.11/logging/__init__.py", line 1644, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.11/logging/__init__.py", line 1706, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.11/logging/__init__.py", line 978, in handle
#     self.emit(record)
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/utils/logging.py",
# line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "/usr/local/lib/python3.11/dist-packages/pip/_vendor/rich/console.py",
# line 1703, in print
#     extend(
#   File "/usr/local/lib/python3.11/dist-packages/pip/_vendor/rich/segment.py",
# line 197, in <genexpr>
#     result_segments = (
#                       ^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_vendor/rich/console.py",
# line 1310, in render
#     renderable = rich_cast(renderable)
#                  ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_vendor/rich/protocol.py",
# line 30, in rich_cast
#     rich_visited_set: Set[type] = set()  # Prevent potential infinite loop
#                                   ^^^^^
# KeyboardInterrupt
#    ━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━ 32.8/56.3 MB 208.4 MB/s eta 0:00:01
# ^C

# %%
import zipfile
import os
import shutil

# Replace 'your_uploaded_file.zip' with the actual name of your uploaded zip file
zip_file_path = 'python_client.zip'

# Create a directory to extract the files into (optional)
extract_dir = 'extracted_files'
os.makedirs(extract_dir, exist_ok=True)

# Unzip the file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

print(f"File '{zip_file_path}' unzipped successfully to '{extract_dir}'.")
# move out the python_client folder from extracted folders outside
# Define the source and destination paths
source_path = os.path.join(extract_dir, 'python_client')
destination_path = '.' # Move to the current directory (where the notebook is)

# Move the directory
if os.path.exists(source_path):
    shutil.move(source_path, destination_path)
    print(f"Moved '{source_path}' to '{destination_path}'.")
else:
    print(f"Source directory '{source_path}' not found.")

# Now change the directory to python_client
os.chdir('python_client/')
print(f"Changed current directory to: {os.getcwd()}")

# List files in the current directory to verify
print("Files in the current directory:")
print(os.listdir())
# Out:
# File 'python_client.zip' unzipped successfully to 'extracted_files'.
# Moved 'extracted_files/python_client' to '.'.
# Changed current directory to: /content/python_client
# Files in the current directory:
# ['__pycache__', 'debug_training.py', 'train_progressive_portfolio.py', 'run_broker.py', 'market_gateway_client', 'tests', 'train_portfolio_agent.py', 'run_multi_agent_demo.py', 'test_dimensionality_analysis.py', 'requirements.txt', 'train_with_debug.py', 'simple_dimensionality_test.py', 'Dockerfile', 'evaluate_rl_agent.py', 'test_progressive_portfolio.py', 'validate_framework.py', 'environment.yml', 'portfolio_dimensionality_analysis.png', 'rl_agent', 'train_rl_agent.py', 'run_sanity_check.py', 'train_aggressive_agent.py']

# %%
import os
# Set the host and port for the gRPC connection to your local machine
#
os.environ['GRPC_HOST'] = '6.tcp.ngrok.io'
os.environ['GRPC_PORT'] = '12001'
print(f"gRPC host set to: {os.environ['GRPC_HOST']}")
print(f"gRPC port set to: {os.environ['GRPC_PORT']}")
# Out:
# gRPC host set to: 6.tcp.ngrok.io
# gRPC port set to: 12001

# %%
os.path.abspath(os.getcwd())
# Out:
# '/content/python_client'

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)

# %%
# !python run_multi_agent_demo.py
# Out:
# --- Starting Multi-Agent Demo ---
# Make sure the Rust gRPC server is running in a separate terminal.
# Attempting to connect to gRPC server at 6.tcp.ngrok.io:12001...
# [Gateway] Registered new agent: 5ee87e83-ae04-46f7-9c8f-7d47d58bbe0f
# [Agent 5ee87e83] Starting activity...
# [Gateway] Registered new agent: ba200bf6-9469-473c-ad4f-e96247a3b110
# [Agent ba200bf6] Starting activity...
# Started 2 agents. Press Ctrl+C to stop.
# [Agent ba200bf6] ACK: Order 10183619 Status: Confirmed Details: Order confirmed by market
# [Agent 5ee87e83] ACK: Order 10183618 Status: Confirmed Details: Order confirmed by market
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 945@453.36
# [Agent 5ee87e83] ACK: Order 10183620 Status: Confirmed Details: Order confirmed by market
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 12043@453.97
# [Agent 5ee87e83] TRADE: Order 10183620 Stock 17 Filled 896@363.95
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 134@455.19
# [Agent 5ee87e83] TRADE: Order 10183620 Stock 17 Filled 781@363.87
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 943@455.2
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 727@455.2
# [Agent 5ee87e83] TRADE: Order 10183620 Stock 17 Filled 212@363.86
# [L1 Data] Stock: 13, Bid: 404.39 (9900), Ask: 404.63 (1305), Last: 404.63
# [Agent 5ee87e83] TRADE: Order 10183620 Stock 17 Filled 1000@363.85
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 233@455.26
# [Agent 5ee87e83] TRADE: Order 10183620 Stock 17 Filled 176@363.83
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 1000@455.86
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 1000@455.89
# [Agent 5ee87e83] TRADE: Order 10183620 Stock 17 Filled 288@363.82
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 1000@456.75
# [Agent 5ee87e83] TRADE: Order 10183620 Stock 17 Filled 809@363.77
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 100@457.49
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 515@457.8
# [Agent 5ee87e83] TRADE: Order 10183620 Stock 17 Filled 161@363.73
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 584@457.82
# [Agent 5ee87e83] TRADE: Order 10183620 Stock 17 Filled 6257@363.64
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 1000@457.89
# [Agent 5ee87e83] TRADE: Order 10183620 Stock 17 Filled 1000@363.13
# [Agent 5ee87e83] TRADE: Order 10183620 Stock 17 Filled 237@362.62
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 1000@457.92
# [L1 Data] Stock: 3, Bid: 26.91 (8212), Ask: 27.29 (769), Last: 27.29
# [Agent 5ee87e83] TRADE: Order 10183620 Stock 17 Filled 298@362.59
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 72@457.94
# [Agent 5ee87e83] TRADE: Order 10183620 Stock 17 Filled 113@362.57
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 1000@458.15
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 1000@458.18
# [Agent 5ee87e83] TRADE: Order 10183620 Stock 17 Filled 1000@362.48
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 6171@459.02
# [Agent 5ee87e83] TRADE: Order 10183620 Stock 17 Filled 1000@361.8
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 693@459.74
# [Agent 5ee87e83] TRADE: Order 10183620 Stock 17 Filled 906@361.71
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 1000@459.98
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 1000@460.17
# [Agent 5ee87e83] TRADE: Order 10183620 Stock 17 Filled 279@361.71
# [L1 Data] Stock: 7, Bid: 34.57 (2094), Ask: 34.95 (6338), Last: 34.95
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 2192@460.66
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 1000@460.84
# [Agent 5ee87e83] TRADE: Order 10183620 Stock 17 Filled 1000@361.66
# [Agent 5ee87e83] TRADE: Order 10183620 Stock 17 Filled 998@361.61
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 1000@461.18
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 1000@461.6
# [Agent 5ee87e83] TRADE: Order 10183620 Stock 17 Filled 556@361.58
# [Agent 5ee87e83] TRADE: Order 10183620 Stock 17 Filled 361@361.57
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 305@462.72
# [Agent 5ee87e83] TRADE: Order 10183620 Stock 17 Filled 206@361.56
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 26@462.83
# [Agent 5ee87e83] TRADE: Order 10183620 Stock 17 Filled 577@361.55
# [L1 Data] Stock: 17, Bid: 182.40 (3380), Ask: 182.71 (21327), Last: 182.40
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 1000@463.1
# [Agent 5ee87e83] TRADE: Order 10183620 Stock 17 Filled 768@361.53
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 1000@463.25
# [Agent 5ee87e83] TRADE: Order 10183620 Stock 17 Filled 401@361.52
# [Agent 5ee87e83] TRADE: Order 10183620 Stock 17 Filled 1000@361.1
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 1000@463.53
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 5519@463.76
# [Agent 5ee87e83] TRADE: Order 10183620 Stock 17 Filled 1000@360.18
# [Agent 5ee87e83] TRADE: Order 10183620 Stock 17 Filled 5083@360.11
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 962@464.07
# [Agent 5ee87e83] TRADE: Order 10183620 Stock 17 Filled 449@359.4
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 1000@464.17
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 1000@464.17
# [Agent 5ee87e83] TRADE: Order 10183620 Stock 17 Filled 662@359.32
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 1000@464.21
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 5420@464.54
# [L1 Data] Stock: 18, Bid: 460.16 (8176), Ask: 460.96 (11831), Last: 460.16
# [Agent 5ee87e83] TRADE: Order 10183620 Stock 17 Filled 469@359.18
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 1000@464.67
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 1000@465.05
# [Agent 5ee87e83] TRADE: Order 10183620 Stock 17 Filled 4650@358.27
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 1000@465.29
# [Agent 5ee87e83] TRADE: Order 10183620 Stock 17 Filled 1000@357.88
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 1000@465.55
# [Agent ba200bf6] TRADE: Order 10183619 Stock 10 Filled 1000@465.67
# [Agent 5ee87e83] TRADE: Order 10183620 Stock 17 Filled
# [Agent 5ee87e83] TRADE: Order 10183954 Stock 19 Filled 1000@558.32
# [Agent ba200bf6] TRADE: Order 10186520 Stock 14 Filled 9262@444.23
# [Agent ba200bf6] TRADE: Order 10186520 Stock 14 Filled 14415@443.65
# [Agent 5ee87e83] TRADE: Order 10183954 Stock 19 Filled 1000@559.83
# --- Stopping Multi-Agent Demo ---
# Traceback (most recent call last):
#   File "/content/python_client/run_multi_agent_demo.py", line 107, in <module>
#     time.sleep(1)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/python_client/run_multi_agent_demo.py", line 109, in <module>
#     print("--- Stopping Multi-Agent Demo ---")
# KeyboardInterrupt
# ^C

# %%
# !python train_rl_agent.py --history_length 100 --stock-id 1
# Out:
# --- Starting RL Agent Training Playground ---
# Connecting to gRPC server at 6.tcp.ngrok.io:12001...
# [Gateway] Registered new agent: d50b783d-de89-47f9-a36b-5bd6e08dce74
# MarketEnv initialized for single stock: 1
# DEBUG: Inside MarketEnv.__init__, self.observation_space set to: Box(-inf, inf, (100, 7), float32)
# [PPOAgent] Using device: cuda
# Traceback (most recent call last):
#   File "/content/python_client/train_rl_agent.py", line 52, in <module>
#     agent = PPOAgent(
#             ^^^^^^^^^
#   File "/content/python_client/rl_agent/ppo_agent.py", line 20, in __init__
#     self.policy = ActorCritic(input_dims, n_actions).to(self.device)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1343, in to
#     return self._apply(convert)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 903, in _apply
#     module._apply(fn)
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/rnn.py", line 285, in _apply
#     ret = super()._apply(fn, recurse)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 930, in _apply
#     param_applied = fn(param)
#                     ^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py", line 1329, in convert
#     return t.to(
#            ^^^^^
# KeyboardInterrupt
# ^C

# %%
  # !python evaluate_rl_agent.py --stock-id 1
# Out:
# --- Starting RL Agent Evaluation ---
# Connecting to gRPC server at 6.tcp.ngrok.io:12001...
# [Gateway] Registered new agent: 6b8f5b7a-d207-42dc-982b-47a539ecf93b
# MarketEnv initialized for single stock: 1
# DEBUG: Inside MarketEnv.__init__, self.observation_space set to: Box(-inf, inf, (30, 7), float32)
# [PPOAgent] Using device: cuda
# Loaded model from ./rl_agent_models/ppo_model_40.pth
# Evaluating Agent:  15% 1545/10000 [00:03<00:19, 431.59it/s, portfolio_value=-466.66]
# Traceback (most recent call last):
#   File "/content/python_client/evaluate_rl_agent.py", line 57, in <module>
#     action, _, _, _ = agent.policy.get_action(state_tensor)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/python_client/rl_agent/model.py", line 42, in get_action
#     action_dist = Categorical(action_probs)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/distributions/categorical.py", line 72, in __init__
#     super().__init__(batch_shape, validate_args=validate_args)
#   File "/usr/local/lib/python3.11/dist-packages/torch/distributions/distribution.py", line 69, in __init__
#     valid = constraint.check(value)
#             ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/distributions/constraints.py", line 464, in check
#     return torch.all(value >= 0, dim=-1) & ((value.sum(-1) - 1).abs() < 1e-6)
#                                             ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt

# %%
# Phase 1: Master single stock trading
# !python train_progressive_portfolio.py --phase 1 --stock-id 1 --steps 25000

# Phase 2: Learn portfolio allocation
# !python train_progressive_portfolio.py --phase 2 --top-k 5 --steps 50000

# Phase 3: Master sector rotation
# !python train_progressive_portfolio.py --phase 3 --sectors 4 --steps 75000
# Out:
# Starting Progressive Portfolio Training - Phase 1
# ============================================================
# === Phase 1: Single Stock Training (Stock 1) ===
# [Gateway] Registered new agent: 309285e3-2f4f-4ccf-8b68-6104b3591671
# MarketEnv initialized for single stock: 1
# DEBUG: Inside MarketEnv.__init__, self.observation_space set to: Box(-inf, inf, (30, 7), float32)
# [PPOAgent] Using device: cuda
# Training on stock 1 for 25000 steps...
# Step 2048: Reward=-85.10, Portfolio=$1000000.00
# Step 4096: Reward=-65.00, Portfolio=$1000000.00
# Step 6144: Reward=-54.30, Portfolio=$1000000.00
# Step 8192: Reward=-40.30, Portfolio=$1000000.00
# Step 10240: Reward=-30.60, Portfolio=$1000000.00
# Step 12288: Reward=-30.50, Portfolio=$1000000.00
# Step 14336: Reward=-21.00, Portfolio=$1000000.00
# Step 16384: Reward=-7.90, Portfolio=$1000000.00
# Step 18432: Reward=-2.40, Portfolio=$1000000.00
# Step 20480: Reward=-1.80, Portfolio=$1000000.00
# Step 22528: Reward=-1.00, Portfolio=$1000000.00
# Step 24576: Reward=-0.10, Portfolio=$1000000.00
# Phase 1 model saved to ./progressive_portfolio_models/phase1_single_stock.pth
# Training completed!
# Starting Progressive Portfolio Training - Phase 2
# ============================================================
# === Phase 2: Top-5 Portfolio Training ===
# [Gateway] Registered new agent: 745bf8e6-187d-44a1-a3c3-c1d1ac4ad223
# [ContinuousPPOAgent] Using device: cuda
# Training top-5 portfolio for 50000 steps...
# Step 2048: Reward=0.00, Portfolio=$1000000.00, Div=0.00
# Step 4096: Reward=0.00, Portfolio=$1000000.00, Div=0.00
# Phase 2 training interrupted
# Phase 2 model saved to ./progressive_portfolio_models/phase2_top_5_portfolio.pth
# Training completed!
# Starting Progressive Portfolio Training - Phase 3
# ============================================================
# === Phase 3: Sector Rotation Training (4 sectors) ===
# object address  : 0x78fe08281ba0
# object refcount : 2
# object type     : 0x9d7580
# object type name: KeyboardInterrupt
# object repr     : KeyboardInterrupt()
# lost sys.stderr
# ^C

# %%
# Train an agent that MUST trade
# !python train_aggressive_agent.py --env-type aggressive --stock-id 1 --steps 10000

# Or force minimum investment
# !python train_aggressive_agent.py --env-type forced --stock-id 1 --steps 10000

# Or smart aggressive approach
# !python train_aggressive_agent.py --env-type smart --stock-id 1 --steps 10000
# Out:
# 🚀 AGGRESSIVE TRADING AGENT TRAINING
# ==================================================
# Finally! An agent that will actually invest money!
# Environment: aggressive
# Stock: 1
# Steps: 10,000
#
# === Training AGGRESSIVE Agent (Stock 1) ===
# No more sitting on cash like a coward! 💪
# [Gateway] Registered new agent: 674150d7-e083-4e4a-8eb7-23c478b253a1
# AggressivePortfolioEnv initialized for single stock: 1
# Using AggressivePortfolioEnv - No hold action, cash penalties
# [PPOAgent] Using device: cuda
# Environment: 8 actions (NO HOLD ACTION!)
# Agent will be FORCED to trade!
#
# Starting aggressive training for 10000 steps...
#
# Step 2048 - Learning Update #1:
#   💰 Portfolio: $993423.06
#   💵 Cash: $977655.52 (98.4%)
#   📈 Invested: 1.6%
#   📊 Inventory: 69 shares
#   🎯 Reward: -6697.27
#   ✅ Trade Success: 60.5% (1239/2048)
#   🎲 Action Distribution:
#     0 (Market Buy): 12.7%
#     1 (Market Sell): 14.1%
#     2 (Limit Buy -1¢): 10.0%
#     3 (Limit Buy -2¢): 13.5%
#     4 (Limit Buy -3¢): 10.6%
#     5 (Limit Sell +1¢): 11.4%
#     6 (Limit Sell +2¢): 13.4%
#     7 (Limit Sell +3¢): 14.3%
#
# Step 4096 - Learning Update #2:
#   💰 Portfolio: $989849.70
#   💵 Cash: $-749362.81 (-75.7%)
#   📈 Invested: 175.7%
#   📊 Inventory: 7559 shares
#   🎯 Reward: -3641.90
#   ✅ Trade Success: 69.3% (1419/2048)
#   🎲 Action Distribution:
#     0 (Market Buy): 10.8%
#     1 (Market Sell): 15.8%
#     2 (Limit Buy -1¢): 10.7%
#     3 (Limit Buy -2¢): 11.8%
#     4 (Limit Buy -3¢): 9.3%
#     5 (Limit Sell +1¢): 13.8%
#     6 (Limit Sell +2¢): 17.7%
#     7 (Limit Sell +3¢): 10.1%
#
# Step 6144 - Learning Update #3:
#   💰 Portfolio: $974967.23
#   💵 Cash: $1093113.38 (112.1%)
#   📈 Invested: -12.1%
#   📊 Inventory: -515 shares
#   🎯 Reward: -14867.88
#   ✅ Trade Success: 64.2% (1314/2048)
#   🎲 Action Distribution:
#     0 (Market Buy): 9.3%
#     1 (Market Sell): 17.1%
#     2 (Limit Buy -1¢): 15.0%
#     3 (Limit Buy -2¢): 8.3%
#     4 (Limit Buy -3¢): 9.1%
#     5 (Limit Sell +1¢): 10.8%
#     6 (Limit Sell +2¢): 21.0%
#     7 (Limit Sell +3¢): 9.4%
#
# Step 8192 - Learning Update #4:
#   💰 Portfolio: $971208.83
#   💵 Cash: $1337117.78 (137.7%)
#   📈 Invested: -37.7%
#   📊 Inventory: -1595 shares
#   🎯 Reward: -3812.49
#   ✅ Trade Success: 66.8% (1368/2048)
#   🎲 Action Distribution:
#     0 (Market Buy): 6.9%
#     1 (Market Sell): 17.1%
#     2 (Limit Buy -1¢): 11.2%
#     3 (Limit Buy -2¢): 10.4%
#     4 (Limit Buy -3¢): 8.7%
#     5 (Limit Sell +1¢): 21.8%
#     6 (Limit Sell +2¢): 15.2%
#     7 (Limit Sell +3¢): 8.8%
#
# === Final Results ===
# 💰 Final Portfolio: $975450.94
# 💵 Final Cash: $3848581.78 (394.5%)
# 📊 Final Inventory: -12524 shares
# 📈 Investment Ratio: -294.5%
# 😞 Still too much cash - need more aggressive training
# 💾 Final model saved: ./aggressive_models_aggressive/aggressive_final_stock_1.pth
# 🚀 AGGRESSIVE TRADING AGENT TRAINING
# ==================================================
# Finally! An agent that will actually invest money!
# Environment: forced
# Stock: 1
# Steps: 10,000
#
# === Training FORCED Agent (Stock 1) ===
# No more sitting on cash like a coward! 💪
# [Gateway] Registered new agent: c9b13b72-8b68-447c-9d98-f9bf8fc4e9ba
# AggressivePortfolioEnv initialized for single stock: 1
# Using ForceInvestmentEnv - Must invest at least 50%
# [PPOAgent] Using device: cuda
# Environment: 8 actions (NO HOLD ACTION!)
# Agent will be FORCED to trade!
#
# Starting aggressive training for 10000 steps...
#
# Step 2048 - Learning Update #1:
#   💰 Portfolio: $990153.80
#   💵 Cash: $101151.30 (10.2%)
#   📈 Invested: 89.8%
#   📊 Inventory: 3875 shares
#   🎯 Reward: -9922.27
#   ✅ Trade Success: 84.5% (1731/2048)
#   🎲 Action Distribution:
#     0 (Market Buy): 13.4%
#     1 (Market Sell): 11.8%
#     2 (Limit Buy -1¢): 12.7%
#     3 (Limit Buy -2¢): 11.9%
#     4 (Limit Buy -3¢): 10.6%
#     5 (Limit Sell +1¢): 13.8%
#     6 (Limit Sell +2¢): 13.1%
#     7 (Limit Sell +3¢): 12.6%
#
# Step 4096 - Learning Update #2:
#   💰 Portfolio: $985623.40
#   💵 Cash: $1354760.18 (137.5%)
#   📈 Invested: -37.5%
#   📊 Inventory: -1609 shares
#   🎯 Reward: -4766.32
#   ✅ Trade Success: 66.6% (1363/2048)
#   🎲 Action Distribution:
#     0 (Market Buy): 10.5%
#     1 (Market Sell): 9.3%
#     2 (Limit Buy -1¢): 18.8%
#     3 (Limit Buy -2¢): 9.4%
#     4 (Limit Buy -3¢): 17.8%
#     5 (Limit Sell +1¢): 12.0%
#     6 (Limit Sell +2¢): 11.1%
#     7 (Limit Sell +3¢): 11.0%
#   ⚠️  UNDER-INVESTED! Required: 50.0%
#
# Step 6144 - Learning Update #3:
#   💰 Portfolio: $987490.10
#   💵 Cash: $274.33 (0.0%)
#   📈 Invested: 100.0%
#   📊 Inventory: 4303 shares
#   🎯 Reward: -4941.28
#   ✅ Trade Success: 64.0% (1310/2048)
#   🎲 Action Distribution:
#     0 (Market Buy): 11.8%
#     1 (Market Sell): 10.9%
#     2 (Limit Buy -1¢): 28.5%
#     3 (Limit Buy -2¢): 9.7%
#     4 (Limit Buy -3¢): 8.7%
#     5 (Limit Sell +1¢): 9.4%
#     6 (Limit Sell +2¢): 12.1%
#     7 (Limit Sell +3¢): 8.9%
#
# Step 8192 - Learning Update #4:
#   💰 Portfolio: $989208.59
#   💵 Cash: $-2590431.67 (-261.9%)
#   📈 Invested: 361.9%
#   📊 Inventory: 15603 shares
#   🎯 Reward: 1755.59
#   ✅ Trade Success: 39.7% (813/2048)
#   🎲 Action Distribution:
#     0 (Market Buy): 10.4%
#     1 (Market Sell): 8.9%
#     2 (Limit Buy -1¢): 13.2%
#     3 (Limit Buy -2¢): 21.0%
#     4 (Limit Buy -3¢): 15.7%
#     5 (Limit Sell +1¢): 11.9%
#     6 (Limit Sell +2¢): 8.8%
#     7 (Limit Sell +3¢): 10.2%
#
# === Final Results ===
# 💰 Final Portfolio: $990100.57
# 💵 Final Cash: $-3797102.23 (-383.5%)
# 📊 Final Inventory: 20867 shares
# 📈 Investment Ratio: 483.5%
# 🎉 SUCCESS: Agent learned to invest money!
# 💾 Final model saved: ./aggressive_models_forced/aggressive_final_stock_1.pth
# 🚀 AGGRESSIVE TRADING AGENT TRAINING
# ==================================================
# Finally! An agent that will actually invest money!
# Environment: smart
# Stock: 1
# Steps: 10,000
#
# === Training SMART Agent (Stock 1) ===
# No more sitting on cash like a coward! 💪
# [Gateway] Registered new agent: 278ad1f9-384c-4d0d-9fbb-4b27141dcd7e
# AggressivePortfolioEnv initialized for single stock: 1
# Using SmartAggressiveEnv - Balanced aggressive approach
# [PPOAgent] Using device: cuda
# Environment: 8 actions (NO HOLD ACTION!)
# Agent will be FORCED to trade!
#
# Starting aggressive training for 10000 steps...
#
# Step 2048 - Learning Update #1:
#   💰 Portfolio: $991698.47
#   💵 Cash: $-426346.55 (-43.0%)
#   📈 Invested: 143.0%
#   📊 Inventory: 6181 shares
#   🎯 Reward: -8373.45
#   ✅ Trade Success: 81.1% (1660/2048)
#   🎲 Action Distribution:
#     0 (Market Buy): 15.1%
#     1 (Market Sell): 10.1%
#     2 (Limit Buy -1¢): 13.6%
#     3 (Limit Buy -2¢): 10.9%
#     4 (Limit Buy -3¢): 14.0%
#     5 (Limit Sell +1¢): 12.3%
#     6 (Limit Sell +2¢): 12.1%
#     7 (Limit Sell +3¢): 11.9%
#
# Step 4096 - Learning Update #2:
#   💰 Portfolio: $988760.43
#   💵 Cash: $1302154.98 (131.7%)
#   📈 Invested: -31.7%
#   📊 Inventory: -1366 shares
#   🎯 Reward: -3039.88
#   ✅ Trade Success: 56.8% (1164/2048)
#   🎲 Action Distribution:
#     0 (Market Buy): 10.9%
#     1 (Market Sell): 24.6%
#     2 (Limit Buy -1¢): 10.7%
#     3 (Limit Buy -2¢): 10.6%
#     4 (Limit Buy -3¢): 10.5%
#     5 (Limit Sell +1¢): 11.8%
#     6 (Limit Sell +2¢): 10.3%
#     7 (Limit Sell +3¢): 10.6%
#
# Step 6144 - Learning Update #3:
#   💰 Portfolio: $981277.05
#   💵 Cash: $1091398.65 (111.2%)
#   📈 Invested: -11.2%
#   📊 Inventory: -480 shares
#   🎯 Reward: -7528.28
#   ✅ Trade Success: 81.2% (1664/2048)
#   🎲 Action Distribution:
#     0 (Market Buy): 12.7%
#     1 (Market Sell): 18.3%
#     2 (Limit Buy -1¢): 13.2%
#     3 (Limit Buy -2¢): 6.8%
#     4 (Limit Buy -3¢): 8.8%
#     5 (Limit Sell +1¢): 12.6%
#     6 (Limit Sell +2¢): 14.3%
#     7 (Limit Sell +3¢): 13.1%
#
# Step 8192 - Learning Update #4:
#   💰 Portfolio: $974516.19
#   💵 Cash: $191735.15 (19.7%)
#   📈 Invested: 80.3%
#   📊 Inventory: 3412 shares
#   🎯 Reward: -6845.62
#   ✅ Trade Success: 76.5% (1567/2048)
#   🎲 Action Distribution:
#     0 (Market Buy): 10.2%
#     1 (Market Sell): 18.2%
#     2 (Limit Buy -1¢): 9.3%
#     3 (Limit Buy -2¢): 19.5%
#     4 (Limit Buy -3¢): 11.4%
#     5 (Limit Sell +1¢): 9.0%
#     6 (Limit Sell +2¢): 12.1%
#     7 (Limit Sell +3¢): 10.3%
#
# === Final Results ===
# 💰 Final Portfolio: $972519.56
# 💵 Final Cash: $773608.08 (79.5%)
# 📊 Final Inventory: 867 shares
# 📈 Investment Ratio: 20.5%
# 😞 Still too much cash - need more aggressive training
# 💾 Final model saved: ./aggressive_models_smart/aggressive_final_stock_1.pth
